# %%
import pandas as pd

# %%
df = pd.read_csv("data/brewery_data_complete_extended.csv")

# %%
df.head()
# Out:
#    Batch_ID            Brew_Date  Beer_Style   SKU      Location  \
# 0   7870796  2020-01-01 00:00:19  Wheat Beer  Kegs    Whitefield
# 1   9810411  2020-01-01 00:00:31        Sour  Kegs    Whitefield
# 2   2623342  2020-01-01 00:00:40  Wheat Beer  Kegs   Malleswaram
# 3   8114651  2020-01-01 00:01:37         Ale  Kegs   Rajajinagar
# 4   4579587  2020-01-01 00:01:43       Stout  Cans  Marathahalli
#
#    Fermentation_Time  Temperature  pH_Level   Gravity  Alcohol_Content  \
# 0                 16    24.204251  5.289845  1.039504         5.370842
# 1                 13    18.086763  5.275643  1.059819         5.096053
# 2                 12    15.539333  4.778016  1.037476         4.824737
# 3                 17    16.418489  5.345261  1.052431         5.509243
# 4                 18    19.144908  4.861854  1.054296         5.133625
#
#    Bitterness  Color Ingredient_Ratio  Volume_Produced   Total_Sales  \
# 0          20      5      1:0.32:0.16             4666   2664.759345
# ...

# %%
df.shape
# Out:
# (10000000, 20)

# %%
df.sample(2_500_000).to_csv("data/25_brewery_data.csv", index=False)

# %%
df.sample(5_000_000).to_csv("data/50_brewery_data.csv", index=False)

# %%
df.sample(7_500_000).to_csv("data/75_brewery_data.csv", index=False)

# %%
df.groupBy("Location").avg("Quality_Score").show()
# Out:
# +---------------+------------------+
# |       Location|avg(Quality_Score)|
# +---------------+------------------+
# |    Malleswaram| 7.999791201182198|
# |    Indiranagar| 7.999190177534509|
# |      Jayanagar| 7.999973588172222|
# |Electronic City| 7.999527582641294|
# |      Yelahanka|  7.99962445437319|
# |    Rajajinagar| 8.000140583354819|
# |    Koramangala| 7.999395786068067|
# |     HSR Layout| 8.000289485017891|
# |     Whitefield|  8.00043704687677|
# |   Marathahalli| 7.999881250512137|
# +---------------+------------------+

# %%
import pandas as pd

# %%
df = pd.read_csv("data/25_brewery_data.csv")

# %%
df.head()
# Out:
#    Batch_ID            Brew_Date  Beer_Style   SKU      Location  \
# 0   7870796  2020-01-01 00:00:19  Wheat Beer  Kegs    Whitefield
# 1   9810411  2020-01-01 00:00:31        Sour  Kegs    Whitefield
# 2   2623342  2020-01-01 00:00:40  Wheat Beer  Kegs   Malleswaram
# 3   8114651  2020-01-01 00:01:37         Ale  Kegs   Rajajinagar
# 4   4579587  2020-01-01 00:01:43       Stout  Cans  Marathahalli
#
#    Fermentation_Time  Temperature  pH_Level   Gravity  Alcohol_Content  ...  \
# 0                 16    24.204251  5.289845  1.039504         5.370842  ...
# 1                 13    18.086763  5.275643  1.059819         5.096053  ...
# 2                 12    15.539333  4.778016  1.037476         4.824737  ...
# 3                 17    16.418489  5.345261  1.052431         5.509243  ...
# 4                 18    19.144908  4.861854  1.054296         5.133625  ...
#
#    Volume_Produced   Total_Sales Quality_Score  Brewhouse_Efficiency  \
# ...
